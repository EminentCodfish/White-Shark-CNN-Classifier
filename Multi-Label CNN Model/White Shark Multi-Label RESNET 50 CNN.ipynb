# %% [markdown]
# # White Shark Multi-Label CNN
#
# In this version we will be using a local GPU (NVIDIA RTX 2070 8GB card). We will use the vision module under the fast.ai toolbox. This version builds on the previous 'Shark/No Shark' model by adding multi-label classification.

# %%
# %reload_ext autoreload
# %autoreload 2 
# %matplotlib inline

# %% [markdown]
# We import all the necessary packages. We are going to work with the fastai V1 library which sits on top of Pytorch 1.0.

# %%
from fastai.vision import *
from fastai.metrics import error_rate
import numpy as np
#from PIL import ImageFile
#ImageFile.LOAD_TRUNCATED_IMAGES = True

# %% [markdown]
# Set the batch size. We will start with 8 which seems to work with this size GPU.

# %%
bs = 16

# %% [markdown]
# # Import the data

# %% [markdown]
# Set the file path

# %%
path = 'D:\\Population Study Videos\\Training Data\\CNN_training_set\\'

# %% [markdown]
# Look at the labels csv

# %%
df = pd.read_csv(path+'ws_metadata.csv')
df.head()
# Out:
#                           Name                      Label
# 0  20191120-GOPR0104-17062.jpg               Caudal Shark
# 1  20191120-GOPR0104-20011.jpg                 Gill Shark
# 2  20191120-GOPR0104-20028.jpg   Dorsal Gill Pelvic Shark
# 3  20191120-GOPR0104-20039.jpg        Dorsal Pelvic Shark
# 4  20191120-GOPR0104-20048.jpg               Pelvic Shark

# %% [markdown]
# Create a data bunch

# %%
tfms = get_transforms()

# %% [markdown]
# The ImageList contains the file names and associated labels.  The image set was split 80/20 into training and validation set.

# %%
np.random.seed(42)
src = (ImageList.from_csv(path, 'ws_metadata.csv')
       .split_by_rand_pct(0.2)
       .label_from_df(label_delim=' '))

# %% [markdown]
# Rescale images to 224 x 224 and apply data augmentation.

# %%
data = (src.transform(tfms, size=224)
        .databunch().normalize(imagenet_stats))

# %% [markdown]
# Let's look at the data

# %%
data.classes
# Out:
# ['', 'Caudal', 'Dorsal', 'Gill', 'No_shark', 'Pelvic', 'Shark']

# %%
data.show_batch(rows = 4, figsize=(10,10))

# %% [markdown]
# Print the class labels, number of classes, number of images in the training set and the number of images in the validation set

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['', 'Caudal', 'Dorsal', 'Gill', 'No_shark', 'Pelvic', 'Shark'],
#  7,
#  35781,
#  8945)

# %% [markdown]
# # Train the model - RESNET 50

# %% [markdown]
# This model is the resnet50 convolutional neural network, which is a robust, medium sized model. This model is pre-trained on the imagenet dataset. This first iteration of fitting will fine-tune the outputs from the imagenet classes to our classes.

# %% [markdown]
# Set the model architecture

# %%
arch = models.resnet50

# %% [markdown]
# Our base architecture is resnet50 again, but the metrics are a little bit differeent: we use accuracy_thresh instead of accuracy. It was determined the predicition for a given class by picking the final activation that was the biggest, but here, each activation can be 0. or 1. accuracy_thresh selects the ones that are above a certain threshold (set to sigmoid(0.2) or ~0.55) and compares them to the ground truth.

# %%
acc_02 = partial(accuracy_thresh, thresh=0.2)
f_score = partial(fbeta, thresh=0.2)
learn = cnn_learner(data, arch, metrics=[acc_02, f_score])

# %% [markdown]
# We use the LR Finder to pick a good learning rate.

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %% [markdown]
# Fit the model

# %%
lr = 0.01

# %%
learn.fit_one_cycle(10, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.147713</td>
#       <td>0.107855</td>
#       <td>0.935207</td>
#       <td>0.953677</td>
#       <td>16:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.119318</td>
#       <td>0.089662</td>
#       <td>0.950411</td>
#       <td>0.963621</td>
#       <td>15:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.102756</td>
#       <td>0.078115</td>
#       <td>0.954803</td>
#       <td>0.967857</td>
#       <td>15:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.102481</td>
#       <td>0.072650</td>
#       <td>0.960505</td>
#       <td>0.970705</td>
#       <td>15:43</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.091277</td>
#       <td>0.068231</td>
#       <td>0.957103</td>
#       <td>0.971235</td>
#       <td>15:46</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.094430</td>
#       <td>0.071150</td>
#       <td>0.953637</td>
#       <td>0.970544</td>
#       <td>15:45</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.079903</td>
#       <td>0.061094</td>
#       <td>0.968985</td>
#       <td>0.976624</td>
#       <td>15:49</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.080773</td>
#       <td>0.058026</td>
#       <td>0.967101</td>
#       <td>0.976746</td>
#       <td>16:12</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.072674</td>
#       <td>0.057810</td>
#       <td>0.966605</td>
#       <td>0.976932</td>
#       <td>15:50</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.073031</td>
#       <td>0.057466</td>
#       <td>0.967196</td>
#       <td>0.977151</td>
#       <td>15:46</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('ws_multi_label_stage-1')

# %% [markdown]
# Let's unfreeze the last couple layers and fine-tune the convolutional layers to improve the customization.

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(12, slice(1e-5, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_thresh</th>
#       <th>fbeta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.072431</td>
#       <td>0.057444</td>
#       <td>0.965679</td>
#       <td>0.976828</td>
#       <td>15:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.071731</td>
#       <td>0.058731</td>
#       <td>0.965839</td>
#       <td>0.976141</td>
#       <td>15:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.076750</td>
#       <td>0.057739</td>
#       <td>0.968266</td>
#       <td>0.976891</td>
#       <td>15:52</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.070637</td>
#       <td>0.056501</td>
#       <td>0.966701</td>
#       <td>0.977362</td>
#       <td>15:52</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.066258</td>
#       <td>0.055180</td>
#       <td>0.968841</td>
#       <td>0.977624</td>
#       <td>15:52</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.061972</td>
#       <td>0.052330</td>
#       <td>0.970614</td>
#       <td>0.978540</td>
#       <td>15:51</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.056153</td>
#       <td>0.052370</td>
#       <td>0.972563</td>
#       <td>0.979186</td>
#       <td>15:51</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.057504</td>
#       <td>0.048190</td>
#       <td>0.972387</td>
#       <td>0.981175</td>
#       <td>15:49</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.048602</td>
#       <td>0.047626</td>
#       <td>0.976251</td>
#       <td>0.981589</td>
#       <td>15:49</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.044503</td>
#       <td>0.045793</td>
#       <td>0.976140</td>
#       <td>0.981912</td>
#       <td>15:51</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.046198</td>
#       <td>0.046048</td>
#       <td>0.974926</td>
#       <td>0.982117</td>
#       <td>15:52</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.042522</td>
#       <td>0.046222</td>
#       <td>0.975389</td>
#       <td>0.982046</td>
#       <td>15:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.export('WS_Multi_RESNET_50.pkl')
